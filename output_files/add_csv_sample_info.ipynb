# %% [markdown]
# # Adding sample identifying info columns to csv output

# %%
import os
import pandas as pd
os.chdir('/Users/nweir/Dropbox/code/csth-imaging/output_files')

# %%
df = pd.read_csv('lc3_wipi_timelapse_summary_analysis_output.csv')

# %%
print(df)
# Out:
#       Unnamed: 0  Unnamed: 0.1  channel  count  \
# 0              0             0    488.0   23.0
# 1              1             1    488.0   23.0
# 2              2             2    488.0   33.0
# 3              3             3    488.0   36.0
# 4              4             4    561.0    2.0
# 5              5             5    561.0    1.0
# 6              6             6    488.0   18.0
# 7              7             7    488.0   22.0
# 8              8             8    488.0   10.0
# 9              9             9    488.0   20.0
# 10            10            10    561.0    0.0
# 11            11            11    561.0    0.0
# 12            12            12    561.0    0.0
# 13            13            13    561.0    0.0
# 14            14            14    561.0    0.0
# 15            15            15    561.0    0.0
# 16             0             0    488.0   18.0
# 17             1             1    488.0   24.0
# 18             2             2    561.0   41.0
# ...

# %%
fnames = df['filename'].tolist()

# %%
fnames
# Out:
# ['LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
# ...

# %%
split_fnames = [j.split('_') for j in fnames]
stains = [i[0] for i in split_fnames]
cell_line = [i[2] for i in split_fnames]
treatment = [i[3] for i in split_fnames]
czi_id = ['_'.join(i[4:6]) for i in split_fnames]

# %%
df['stains'] = pd.Series(stains)
df['cell_line'] = pd.Series(cell_line)
df['treatment'] = pd.Series(treatment)
df['czi_id'] = pd.Series(czi_id)

# %%
print(df)
# Out:
#       Unnamed: 0  Unnamed: 0.1  channel  count  \
# 0              0             0    488.0   23.0
# 1              1             1    488.0   23.0
# 2              2             2    488.0   33.0
# 3              3             3    488.0   36.0
# 4              4             4    561.0    2.0
# 5              5             5    561.0    1.0
# 6              6             6    488.0   18.0
# 7              7             7    488.0   22.0
# 8              8             8    488.0   10.0
# 9              9             9    488.0   20.0
# 10            10            10    561.0    0.0
# 11            11            11    561.0    0.0
# 12            12            12    561.0    0.0
# 13            13            13    561.0    0.0
# 14            14            14    561.0    0.0
# 15            15            15    561.0    0.0
# 16             0             0    488.0   18.0
# 17             1             1    488.0   24.0
# 18             2             2    561.0   41.0
# ...

# %%
df.to_csv('/Users/nweir/Dropbox/code/csth-imaging/output_files/lc3_wipi_timelapse_summary_analysis_output.csv',
         index=False)

# %%
df = pd.read_csv('lc3_wipi_timelapse_raw_analysis_output.csv')

# %%
print(df)
# Out:
#        Unnamed: 0  Unnamed: 0.1  channel  \
# 0               0             0    488.0
# 1               1             1    488.0
# 2               2             2    488.0
# 3               3             3    488.0
# 4               4             4    488.0
# 5               5             5    488.0
# 6               6             6    488.0
# 7               7             7    488.0
# 8               8             8    488.0
# 9               9             9    488.0
# 10             10            10    488.0
# 11             11            11    488.0
# 12             12            12    488.0
# 13             13            13    488.0
# 14             14            14    488.0
# 15             15            15    488.0
# 16             16            16    488.0
# 17             17            17    488.0
# 18             18            18    488.0
# 19             19            19    488.0
# 20             20            20    488.0
# 21             21            21    488.0
# ...

# %%
fnames = df['filename'].tolist()

# %%
fnames
# Out:
# ['LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
#  'LC3-WIPI_HEK_dAtg7_3hrTor_4Pos_2_AiryscanProcessing.czi',
# ...

# %%
split_fnames = [j.split('_') for j in fnames]
stains = [i[0] for i in split_fnames]
cell_line = [i[2] for i in split_fnames]
treatment = [i[3] for i in split_fnames]
czi_id = ["_".join(i[4:6]) for i in split_fnames]

# %%
df['stains'] = pd.Series(stains)
df['cell_line'] = pd.Series(cell_line)
df['treatment'] = pd.Series(treatment)
df['czi_id'] = pd.Series(czi_id)

# %%
print(df)
# Out:
#        Unnamed: 0  Unnamed: 0.1  channel  \
# 0               0             0    488.0
# 1               1             1    488.0
# 2               2             2    488.0
# 3               3             3    488.0
# 4               4             4    488.0
# 5               5             5    488.0
# 6               6             6    488.0
# 7               7             7    488.0
# 8               8             8    488.0
# 9               9             9    488.0
# 10             10            10    488.0
# 11             11            11    488.0
# 12             12            12    488.0
# 13             13            13    488.0
# 14             14            14    488.0
# 15             15            15    488.0
# 16             16            16    488.0
# 17             17            17    488.0
# 18             18            18    488.0
# 19             19            19    488.0
# 20             20            20    488.0
# 21             21            21    488.0
# ...

# %%
df.to_csv('/Users/nweir/Dropbox/code/csth-imaging/output_files/lc3_wipi_timelapse_raw_analysis_output.csv',
         index=False)

# %% [markdown]
# Combining this all for Tina:

# %%
import pandas as pd  # my preferred data container package for python
path_to_csv = ''  # put path to the csv file in quotes
df = pd.read_csv(path_to_csv)  # reads the .csv file into a pandas dataframe
fnames = df['filename'].tolist()  # extract filename column from df and make it a list
# next, make a new list where each list item is another list.
# each item of this sub-list is part of the filename string, split by underscores.
split_fnames = [j.split('_') for j in fnames]
# extract the stain, parent, cell line, treatment, etc. from the split_fnames list of lists.
# make a list from each which will be the stain, parent, etc. for each row of df.
# below is an example of doing this from one of the analysis files; the index will depend
# on how it was ordered in the filename.
stains = [i[0] for i in split_fnames]
parent = [i[1] for i in split_fnames]
cell_line = [i[2] for i in split_fnames]
treatment = [i[3] for i in split_fnames]
czi_id = [i[5] for i in split_fnames]
# add columns to df for each new ID from above
df['stains'] = pd.Series(stains)
df['cell_line'] = pd.Series(cell_line)
df['strain'] = pd.Series(strain)
df['treatment'] = pd.Series(treatment)
df.to_csv('/path/to/output.csv',  # replace this path with your destination path
         index=False)  # optional; if index=True, a column will be made that numbers each row.
